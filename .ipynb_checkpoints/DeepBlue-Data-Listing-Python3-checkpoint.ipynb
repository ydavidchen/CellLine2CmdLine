# %%
################################################################################
## Query Histone Modification Data Sets on DeepBlue Repository
## Adapted from DeepBlue API Examples

## Notes: 
## 1. The original script's modules don't work for python3.5. I updated a few commands
## 2. Python 2.6 or higher is required
################################################################################

## Connect to the server:
# import xmlrpclib #doesn't work on python3
import xmlrpc
import xmlrpc.client
#import xmlrpc.server

# %%
## Set up the client:
url = "http://deepblue.mpi-inf.mpg.de/xmlrpc"
#server = xmlrpclib.Server(url, allow_none=True)
server = xmlrpc.client.ServerProxy(url, encoding='UTF-8', allow_none=True) #adapted for python3

## Use an anonymous key
## Alternatively, you can use your own key
user_key = "anonymous_key"

# %%
## List all projects
server.list_projects(user_key)
# The result will be similar to ['okay', [['p1', 'ENCODE'], ['p2', 'BLUEPRINT Epigenome'], ['p5', 'Roadmap Epigenomics']]]
# Out:
# ['okay',
#  [['p1', 'ENCODE'],
#   ['p2', 'BLUEPRINT Epigenome'],
#   ['p5', 'Roadmap Epigenomics'],
#   ['p7', 'BLUEPRINT HSC differentiation']]]

# %%
help(server.list_experiments)
# Out:
# Help on _Method in module xmlrpc.client object:
#
# class _Method(builtins.object)
#  |  Methods defined here:
#  |
#  |  __call__(self, *args)
#  |      Call self as a function.
#  |
#  |  __getattr__(self, name)
#  |
#  |  __init__(self, send, name)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
## List all registered epigenetic marks: 
server.lst_epigenetic_marks(None, user_key)
# Part of the output will be ['okay', [['em1', 'DNA Methylation'], ['em10', 'Input'], ['em100', 'H3K9/14ac'], ['em101', 'H4K12ac'], ...
# Out:
# ['okay',
#  [['em1', 'DNA Methylation'],
#   ['em10', 'Input'],
#   ['em100', 'H3K9/14ac'],
#   ['em101', 'H4K12ac'],
#   ['em102', 'H4K12bio'],
#   ['em103', 'H4K16ac'],
#   ['em104', 'H4K16ar'],
#   ['em105', 'H4K20me1'],
#   ['em106', 'H4K20me2'],
#   ['em107', 'H4K20me3'],
#   ['em108', 'H4K5ac'],
#   ['em109', 'H4K8ac'],
#   ['em11', 'Control'],
#   ['em110', 'H4K8bio'],
#   ['em111', 'H4K91ac'],
#   ['em112', 'H4K91ub'],
#   ['em113', 'H4R3ci'],
#   ['em114', 'H4R3me1'],
#   ['em115', 'H4R3me2'],
#   ['em116', 'H4S1ph'],
#   ['em117', 'H2AT120ph'],
#   ['em118', 'H1T153ph'],
#   ['em119', 'H3K36me1'],
#   ['em12', 'Regulatory Elements'],
#   ['em120', 'H3K79me1'],
#   ['em121', 'H3K79me3'],
#   ['em122', 'H1S171ph'],
#   ['em123', 'H3.3'],
#   ['em124', 'H3a'],
#   ['em125', 'H3d'],
#   ['em126', 'H2AC'],
#   ['em127', 'H2Aa4'],
#   ['em128', 'H4b'],
#   ['em129', 'H2A.Z'],
#   ['em130', 'H2A.Zac'],
#   ['em131', 'H2ab'],
#   ['em132', 'H2ah'],
#   ['em133', 'H2aa'],
#   ['em134', 'H2a'],
#   ['em135', 'H2ba'],
#   ['em136', 'H2bb'],
#   ['em137', 'H2bf'],
#   ['em138', 'H3.3C'],
#   ['em139', 'H2bc'],
#   ['em14', 'Gene Expression'],
#   ['em140', 'H2A.J'],
#   ['em141', 'H2B'],
#   ['em15', 'H1K186me1'],
#   ['em16', 'H1K25ac'],
#   ['em17', 'H1K25me1'],
#   ['em18', 'H1S172ph'],
#   ['em19', 'H1S17ph'],
#   ['em2', 'DNaseI'],
#   ['em20', 'H1S186ph'],
#   ['em21', 'H1S188ph'],
#   ['em22', 'H1S26ph'],
#   ['em23', 'H1T10ph'],
#   ['em24', 'H1T137ph'],
#   ['em25', 'H1T145ph'],
#   ['em26', 'H1T154ph'],
#   ['em27', 'H1T17ph'],
#   ['em28', 'H1T30ph'],
#   ['em29', 'H2AK119ub'],
#   ['em3', 'TFBS'],
#   ['em30', 'H2AK121ub'],
#   ['em31', 'H2AK125bio'],
#   ['em32', 'H2AK127bio'],
#   ['em33', 'H2AK129bio'],
#   ['em34', 'H2AK13ar'],
#   ['em35', 'H2AK13bio'],
#   ['em36', 'H2AK5ac'],
#   ['em37', 'H2AK9ac'],
#   ['em38', 'H2AK9bio'],
#   ['em39', 'H2AR3ci'],
#   ['em4', 'Chromatin State Segmentation'],
#   ['em40', 'H2AR3me2'],
#   ['em41', 'H2AS137ph'],
#   ['em42', 'H2AS139ph'],
#   ['em43', 'H2AS1ph'],
#   ['em44', 'H2AY142ph'],
#   ['em45', 'H2BK120ac'],
#   ['em46', 'H2BK120ub'],
#   ['em47', 'H2BK12ac'],
#   ['em48', 'H2BK15ac'],
#   ['em49', 'H2BK16ac'],
#   ['em5', 'RNA'],
#   ['em50', 'H2BK20ac'],
#   ['em51', 'H2BK30ar'],
#   ['em52', 'H2BK46ac'],
#   ['em53', 'H2BK5ac'],
#   ['em54', 'H2BK5me1'],
#   ['em55', 'H2BS14ph'],
#   ['em56', 'H3K14ac'],
#   ['em57', 'H3K18ac'],
#   ['em58', 'H3K18bio'],
#   ['em59', 'H3K23ac'],
#   ['em6', 'mRNA'],
#   ['em60', 'H3K27ac'],
#   ['em61', 'H3K27ar'],
#   ['em62', 'H3K27me1'],
#   ['em63', 'H3K27me2'],
#   ['em64', 'H3K27me3'],
#   ['em65', 'H3K36ac'],
#   ['em66', 'H3K36me2'],
#   ['em67', 'H3K36me3'],
#   ['em68', 'H3K37ar'],
#   ['em69', 'H3K4ac'],
#   ['em7', 'flRNA'],
#   ['em70', 'H3K4me1'],
#   ['em71', 'H3K4me2'],
#   ['em72', 'H3K4me3'],
#   ['em73', 'H3K56ac'],
#   ['em74', 'H3K79me2'],
#   ['em75', 'H3K9ac'],
#   ['em76', 'H3K9bio'],
#   ['em77', 'H3K9me1'],
#   ['em78', 'H3K9me2'],
#   ['em79', 'H3K9me3'],
#   ['em8', 'tRNA'],
#   ['em80', 'H3K23me2'],
#   ['em81', 'H3R17ci'],
#   ['em82', 'H3R17me1'],
#   ['em83', 'H3R17me2'],
#   ['em84', 'H3R26ci'],
#   ['em85', 'H3R26me1'],
#   ['em86', 'H3R2ci'],
#   ['em87', 'H3R2me1'],
#   ['em88', 'H3R2me2'],
#   ['em89', 'H3R8ci'],
#   ['em9', 'snRNA'],
#   ['em90', 'H3R8me2'],
#   ['em91', 'H3S10ph'],
#   ['em92', 'H3S28ph'],
#   ['em93', 'H3S31ph'],
#   ['em94', 'H3S6ph'],
#   ['em95', 'H3T11ph'],
#   ['em96', 'H3T3ph'],
#   ['em97', 'H3T45ph'],
#   ['em98', 'H3T6ph'],
#   ['em99', 'H3Y41ph'],
#   ['em142', 'rabbit-IgG-control'],
#   ['em143', 'DDX52'],
#   ['em145', 'EEF2'],
#   ['em146', 'Non-specific target control'],
#   ['em147', 'SRP68'],
#   ['em148', 'UCHL5'],
#   ['em149', 'TFIP11'],
#   ['em151', 'SERBP1'],
#   ['em153', 'RRP9'],
#   ['em154', 'XRN2'],
#   ['em155', 'RPS19'],
#   ['em157', 'NONO'],
#   ['em158', 'PES1'],
#   ['em159', 'GEMIN5'],
#   ['em160', 'PRPF8'],
#   ['em161', 'DDX51'],
#   ['em162', 'EFTUD2'],
#   ['em163', 'FAM120A'],
#   ['em164', 'DDX27'],
#   ['em165', 'CSTF2'],
#   ['em166', 'BCLAF1'],
#   ['em169', 'UPF2'],
#   ['em170', 'TROVE2'],
#   ['em171', 'RPS2'],
#   ['em172', 'RPS5'],
#   ['em173', 'RPLP0'],
#   ['em174', 'RCC2'],
#   ['em175', 'RPL23A'],
#   ['em176', 'PSIP1'],
#   ['em177', 'PKM'],
#   ['em180', 'NUSAP1'],
#   ['em181', 'METAP2'],
#   ['em182', 'NIP7'],
#   ['em186', 'CCAR2'],
#   ['em187', 'GRWD1'],
#   ['em188', 'GNB2L1'],
#   ['em189', 'LSM11'],
#   ['em193', 'AARS'],
#   ['em194', 'RPS10'],
#   ['em196', 'SMNDC1'],
#   ['em200', 'SLTM'],
#   ['em201', 'ZRANB2'],
#   ['em202', 'SRSF5'],
#   ['em203', 'TRA2A'],
#   ['em205', 'SUB1'],
#   ['em206', 'GTF2F1'],
#   ['em207', 'HLTF'],
#   ['em208', 'FUS'],
#   ['em209', 'IGF2BP1'],
#   ['em212', 'PCBP2'],
#   ['em213', 'FASTKD2'],
#   ['em216', 'AGO1'],
#   ['em217', 'DDX24'],
#   ['em218', 'DDX21'],
#   ['em219', 'DAZAP1'],
#   ['em221', 'AATF'],
#   ['em222', 'SSB'],
#   ['em223', 'SRSF4'],
#   ['em224', 'NFX1'],
#   ['em226', 'TIA1'],
#   ['em227', 'TAF15'],
#   ['em228', 'SRSF9'],
#   ['em229', 'SRSF7'],
#   ['em230', 'SRSF1'],
#   ['em232', 'NELFE'],
#   ['em233', 'RECQL'],
#   ['em235', 'QKI'],
#   ['em236', 'PTBP1'],
#   ['em237', 'PCBP1'],
#   ['em238', 'NCBP2'],
#   ['em239', 'PABPC4'],
#   ['em241', 'MATR3'],
#   ['em242', 'IGF2BP3'],
#   ['em243', 'IGF2BP2'],
#   ['em244', 'KHSRP'],
#   ['em245', 'EIF4B'],
#   ['em246', 'HNRNPK'],
#   ['em248', 'FXR1'],
#   ['em249', 'DDX6'],
#   ['em253', 'DDX3X'],
#   ['em254', 'CIRBP'],
#   ['em255', 'AKAP1'],
#   ['em256', 'EIF4A3'],
#   ['em257', 'TARDBP'],
#   ['em258', 'RBM22'],
#   ['em259', 'TBRG4'],
#   ['em260', 'U2AF1'],
#   ['em261', 'RBM15'],
#   ['em262', 'FXR2'],
#   ['em264', 'EWSR1'],
#   ['em265', 'CELF1'],
#   ['em268', 'PPIL4'],
#   ['em270', 'HNRNPU'],
#   ['em271', 'HNRNPC'],
#   ['em272', 'SF1'],
#   ['em276', 'DDX47'],
#   ['em275', 'CNOT8'],
#   ['em277', 'RBM3'],
#   ['em279', 'CCNT2'],
#   ['em280', 'BRF2'],
#   ['em281', 'ATF3'],
#   ['em283', 'GTF3C2'],
#   ['em284', 'BRF1'],
#   ['em285', 'SIRT6'],
#   ['em286', 'BDP1'],
#   ['em287', 'POLR3A'],
#   ['em288', 'ATF1'],
#   ['em289', 'eGFP-JUNB'],
#   ['em290', 'ZZZ3'],
#   ['em292', 'SUPT20H'],
#   ['em293', 'KAT2A'],
#   ['em294', 'eGFP-HDAC8'],
#   ['em295', 'eGFP-JUND'],
#   ['em296', 'NFYA'],
#   ['em297', 'eGFP-NR4A1'],
#   ['em299', 'eGFP-FOS'],
#   ['em300', 'SMARCB1'],
#   ['em301', 'CTCF'],
#   ['em302', 'RAD21'],
#   ['em303', 'EBF1'],
#   ['em304', 'RCOR1'],
#   ['em305', 'BRCA1'],
#   ['em306', 'SMC3'],
#   ['em307', 'NRF1'],
#   ['em308', 'CHD2'],
#   ['em309', 'POLR3G'],
#   ['em310', 'POLR2A'],
#   ['em311', 'RFX5'],
#   ['em312', 'TAL1'],
#   ['em313', 'EP300'],
#   ['em314', 'TBP'],
#   ['em315', 'USF2'],
#   ['em316', 'CEBPB'],
#   ['em317', 'STAT1'],
#   ['em318', 'mouse-IgG-control'],
#   ['em319', 'POLR2AphosphoS2'],
#   ['em320', 'SMARCA4'],
#   ['em321', 'MAX'],
#   ['em322', 'TCF7L2'],
#   ['em323', 'MXI1'],
#   ['em324', 'GATA1'],
#   ['em325', 'MAFK'],
#   ['em326', 'JUND'],
#   ['em327', 'BHLHE40'],
#   ['em328', 'UBTF'],
#   ['em329', 'JUN'],
#   ['em330', 'MAZ'],
#   ['em331', 'ZNF143'],
#   ['em332', 'ZNF384'],
#   ['em333', 'ZC3H11A'],
#   ['em334', 'ZMIZ1'],
#   ['em335', 'ELK1'],
#   ['em336', 'ARID3A'],
#   ['em337', 'SREBF2'],
#   ['em338', 'HCFC1'],
#   ['em339', 'CHD1'],
#   ['em340', 'CUX1'],
#   ['em341', 'SREBF1'],
#   ['em342', 'WRNIP1'],
#   ['em343', 'NFE2'],
#   ['em344', 'IRF3'],
#   ['em345', 'E2F4'],
#   ['em346', 'SIN3A'],
#   ['em347', 'YY1'],
#   ['em348', 'E2F6'],
#   ['em349', 'ZNF274'],
#   ['em351', 'SETDB1'],
#   ['em352', 'NR2C2'],
#   ['em353', 'ZNF263'],
#   ['em354', 'RELA'],
#   ['em355', 'PPARGC1A'],
#   ['em356', 'HNF4A'],
#   ['em357', 'HSF1'],
#   ['em358', 'NR3C1'],
#   ['em359', 'ESRRA'],
#   ['em360', 'MAFF'],
#   ['em361', 'ELK4'],
#   ['em362', 'TRIM28'],
#   ['em363', 'FOS'],
#   ['em364', 'goat-IgG-control'],
#   ['em365', 'CEBPZ'],
#   ['em367', 'IKZF1'],
#   ['em368', 'IRF1'],
#   ['em369', 'TBL1XR1'],
#   ['em370', 'MYC'],
#   ['em371', 'BACH1'],
#   ['em372', 'HA-E2F1'],
#   ['em373', 'ZBTB33'],
#   ['em374', 'POLR2AphosphoS5'],
#   ['em375', 'TEAD4'],
#   ['em376', 'SP1'],
#   ['em377', 'SRF'],
#   ['em378', 'EGR1'],
#   ['em380', 'USF1'],
#   ['em381', 'REST'],
#   ['em382', 'ELF1'],
#   ['em384', 'ESR1'],
#   ['em386', 'GATA3'],
#   ['em387', 'SUZ12'],
#   ['em389', 'E2F1'],
#   ['em391', 'SMARCC2'],
#   ['em392', 'SMARCC1'],
#   ['em393', 'PRDM1'],
#   ['em394', 'ZKSCAN1'],
#   ['em395', 'PML'],
#   ['em396', 'NR2F2'],
#   ['em397', 'TCF12'],
#   ['em398', 'GABPA'],
#   ['em399', 'FOXM1'],
#   ['em400', 'FOSL2'],
#   ['em401', 'HDAC2'],
#   ['em402', 'PBX3'],
#   ['em403', 'CREB1'],
#   ['em404', 'SIX5'],
#   ['em406', 'SP4'],
#   ['em407', 'ATF2'],
#   ['em408', 'BCL3'],
#   ['em409', 'TAF1'],
#   ['em410', 'SP2'],
#   ['em411', 'ETS1'],
#   ['em412', 'POU5F1'],
#   ['em413', 'NANOG'],
#   ['em414', 'TAF7'],
#   ['em415', 'RXRA'],
#   ['em416', 'BCL11A'],
#   ['em417', 'FOXP2'],
#   ['em418', 'PHF8'],
#   ['em419', 'CHD7'],
#   ['em420', 'EZH2'],
#   ['em421', 'H2AFZ'],
#   ['em422', 'RNF2'],
#   ['em423', 'HDAC1'],
#   ['em424', 'WHSC1'],
#   ['em425', 'KDM5B'],
#   ['em426', 'SAP30'],
#   ['em427', 'RBBP5'],
#   ['em428', 'KAT2B'],
#   ['em429', 'NCOR1'],
#   ['em430', 'CREBBP'],
#   ['em431', 'KDM4A'],
#   ['em432', 'KDM1A'],
#   ['em433', 'CBX8'],
#   ['em434', 'CHD4'],
#   ['em435', 'HDAC6'],
#   ['em436', 'CBX2'],
#   ['em437', 'KDM5A'],
#   ['em438', 'ZBTB7A'],
#   ['em439', 'NFIC'],
#   ['em440', 'TCF3'],
#   ['em441', 'T7-control'],
#   ['em442', 'ELAVL1'],
#   ['em443', 'PABPC1'],
#   ['em444', 'MBD4'],
#   ['em445', 'CTCFL'],
#   ['em447', 'THAP1'],
#   ['em448', 'XRCC4'],
#   ['em449', 'CEBPD'],
#   ['em450', 'NFATC1'],
#   ['em451', 'STAT2'],
#   ['em452', 'ZEB1'],
#   ['em453', 'MEF2C'],
#   ['em454', 'RUNX3'],
#   ['em455', 'STAT5A'],
#   ['em457', 'MEF2A'],
#   ['em458', 'SPI1'],
#   ['em459', 'POU2F2'],
#   ['em461', 'MYBL2'],
#   ['em462', 'PAX5'],
#   ['em463', 'IRF4'],
#   ['em464', 'SLBP'],
#   ['em465', 'HNRNPM'],
#   ['em466', 'HNRNPA1'],
#   ['em467', 'FMR1'],
#   ['em468', 'DDX42'],
#   ['em469', 'AUH'],
#   ['em470', 'RBFOX2'],
#   ['em471', 'EIF4G1'],
#   ['em472', 'EIF4G2'],
#   ['em474', 'TIAL1'],
#   ['em475', 'GATA4'],
#   ['em476', 'rat-IgG-control'],
#   ['em477', 'MYB'],
#   ['em478', 'FLI1'],
#   ['em479', 'MYOG'],
#   ['em480', 'MYOD1'],
#   ['em481', 'H3ac'],
#   ['em482', 'HNRNPAB'],
#   ['em483', 'HNRNPD'],
#   ['em484', 'HNRNPA0'],
#   ['em486', 'SRFBP1'],
#   ['em487', 'ILF3'],
#   ['em488', 'PARN'],
#   ['em491', 'EIF3A'],
#   ['em492', 'DNAJC21'],
#   ['em493', 'DNAJC2'],
#   ['em494', 'DHX30'],
#   ['em495', 'DDX1'],
#   ['em496', 'YBX3'],
#   ['em497', 'CPSF7'],
#   ['em498', 'CCAR1'],
#   ['em499', 'ADAR'],
#   ['em500', 'SMN1'],
#   ['em501', 'XPO5'],
#   ['em502', 'STIP1'],
#   ['em503', 'SUCLG1'],
#   ['em504', 'TUFM'],
#   ['em505', 'UBE2L3'],
#   ['em506', 'SBDS'],
#   ['em507', 'SART3'],
#   ['em508', 'RPS3A'],
#   ['em509', 'RBM47'],
#   ['em510', 'PUM2'],
#   ['em511', 'PUM1'],
#   ['em512', 'PUF60'],
#   ['em514', 'NOL12'],
#   ['em515', 'HNRNPL'],
#   ['em516', 'ILF2'],
#   ['em517', 'HNRNPA2B1'],
#   ['em518', 'GRSF1'],
#   ['em519', 'FASTKD1'],
#   ['em521', 'APOBEC3C'],
#   ['em13', 'Chromosome conformation capture'],
#   ['em144', 'DDX55'],
#   ['em150', 'SUPV3L1'],
#   ['em152', 'EIF3D'],
#   ['em156', 'PA2G4'],
#   ['em167', 'DDX28'],
#   ['em168', 'BCCIP'],
#   ['em178', 'RBM27'],
#   ['em179', 'PHF6'],
#   ['em183', 'MARK2'],
#   ['em184', 'LIN28B'],
#   ['em185', 'LARP7'],
#   ['em190', 'FKBP4'],
#   ['em191', 'DDX59'],
#   ['em192', 'RTF1'],
#   ['em195', 'U2AF2'],
#   ['em197', 'RAVER1'],
#   ['em198', 'SND1'],
#   ['em199', 'XRCC5'],
#   ['em204', 'PRPF6'],
#   ['em210', 'XRCC6'],
#   ['em211', 'RBM34'],
#   ['em214', 'EXOSC9'],
#   ['em215', 'EIF3G'],
#   ['em220', 'CSTF2T'],
#   ['em225', 'RPS3'],
#   ['em231', 'SF3B4'],
#   ['em234', 'RBM25'],
#   ['em240', 'MAGOH'],
#   ['em247', 'G3BP2'],
#   ['em250', 'G3BP1'],
#   ['em251', 'ASCC1'],
#   ['em252', 'EIF2S1'],
#   ['em263', 'FUBP3'],
#   ['em266', 'CPSF6'],
#   ['em267', 'POLR2G'],
#   ['em269', 'PAPOLA'],
#   ['em273', 'AGO3'],
#   ['em274', 'AGO2'],
#   ['em278', 'HMGN3'],
#   ['em282', 'GTF2B'],
#   ['em291', 'NFYB'],
#   ['em298', 'eGFP-GATA2'],
#   ['em350', 'GATA2'],
#   ['em366', 'STAT3'],
#   ['em379', 'CBX3'],
#   ['em383', 'FOSL1'],
#   ['em385', 'FOXA1'],
#   ['em388', 'ZNF217'],
#   ['em390', 'CTBP2'],
#   ['em405', 'FOXA2'],
#   ['em446', 'HNF4G'],
#   ['em456', 'MTA3'],
#   ['em460', 'BATF'],
#   ['em473', 'SAFB2'],
#   ['em485', 'TRIM56'],
#   ['em489', 'KHDRBS1'],
#   ['em490', 'HNRNPF'],
#   ['em513', 'PNPT1'],
#   ['em520', 'CNOT7'],
#   ['em522', 'DGCR8'],
#   ['em523', 'EIF2S2'],
#   ['em524', 'CBX1'],
#   ['em525', 'ZBED1'],
#   ['em526', 'SMAD5'],
#   ['em527', 'eGFP-ILK'],
#   ['em528', 'eGFP-DDX20'],
#   ['em529', 'eGFP-ID3'],
#   ['em530', 'eGFP-ZNF24'],
#   ['em531', 'eGFP-TEAD2'],
#   ['em532', 'eGFP-TSC22D4'],
#   ['em533', 'eGFP-KLF13'],
#   ['em534', 'eGFP-PYGO2'],
#   ['em535', 'eGFP-NFE2L1'],
#   ['em536', 'eGFP-IRF1'],
#   ['em537', 'eGFP-HINFP'],
#   ['em538', 'eGFP-ETV1'],
#   ['em539', 'eGFP-DIDO1'],
#   ['em540', 'eGFP-CREB3'],
#   ['em541', 'eGFP-TAF7'],
#   ['em542', 'eGFP-MAFG'],
#   ['em543', 'eGFP-PTTG1'],
#   ['em544', 'eGFP-IRF9'],
#   ['em545', 'eGFP-PTRF'],
#   ['em546', 'eGFP-KLF1'],
#   ['em547', 'eGFP-RELA'],
#   ['em548', 'eGFP-CEBPB'],
#   ['em549', 'DPF2'],
#   ['em550', 'ARNT'],
#   ['em551', 'eGFP-ATF1'],
#   ['em552', 'FOXK2'],
#   ['em553', 'CTBP1'],
#   ['em554', 'HMBOX1'],
#   ['em555', 'DEAF1'],
#   ['em556', 'MYNN'],
#   ['em557', 'DDX20'],
#   ['em558', 'ZNF24'],
#   ['em559', 'TCF7'],
#   ['em560', 'EED'],
#   ['em561', 'ZBTB11'],
#   ['em562', 'TFAP4'],
#   ['em563', 'KDM4B'],
#   ['em564', 'JUNB'],
#   ['em565', 'RUNX1'],
#   ['em566', 'YTHDC2'],
#   ['em567', 'TRIP6'],
#   ['em568', 'SUPT6H'],
#   ['em569', 'SSRP1'],
#   ['em570', 'SUGP2'],
#   ['em571', 'STAU1'],
#   ['em572', 'SNRNP200'],
#   ['em573', 'SFPQ'],
#   ['em574', 'RBM17'],
#   ['em575', 'RBM39'],
#   ['em576', 'PPIG'],
#   ['em577', 'PPP1R8'],
#   ['em578', 'NPM1'],
#   ['em579', 'PABPN1'],
#   ['em580', 'MSI2'],
#   ['em581', 'LARP4'],
#   ['em582', 'HSPD1'],
#   ['em583', 'HNRNPUL1'],
#   ['em584', 'FIP1L1'],
#   ['em585', 'DROSHA'],
#   ['em586', 'BUD13'],
#   ['em587', 'ABCF1'],
#   ['em588', 'ESF1'],
#   ['em589', 'PUS1'],
#   ['em590', 'NUFIP2'],
#   ['em591', 'NAA15'],
#   ['em592', 'NKRF'],
#   ['em593', 'KIF1C'],
#   ['em594', 'KRR1'],
#   ['em595', 'HDGF'],
#   ['em596', 'DKC1'],
#   ['em597', 'DDX19B'],
#   ['em598', 'CKAP4'],
#   ['em599', 'CALR'],
#   ['em600', 'ATP5C1'],
#   ['em601', 'AKAP8L'],
#   ['em602', 'AKAP8'],
#   ['em603', 'ACO1'],
#   ['em604', 'DEK'],
#   ['em605', 'BMI1'],
#   ['em606', 'SIN3B'],
#   ['em607', 'TFDP1'],
#   ['em608', 'CREM'],
#   ['em609', 'ETV6'],
#   ['em610', 'ZHX2'],
#   ['em611', 'CBX5'],
#   ['em612', 'MITF'],
#   ['em613', 'UPF1'],
#   ['em614', 'ZNF622'],
#   ['em615', 'RPS11'],
#   ['em616', 'MTPAP'],
#   ['em617', 'AGGF1'],
#   ['em618', 'YWHAG'],
#   ['em619', 'TNRC6A'],
#   ['em620', 'GNL3'],
#   ['em621', 'SF3A3'],
#   ['em622', 'HNRNPH1'],
#   ['em623', 'DNMT1'],
#   ['em624', 'WDR5'],
#   ['em625', 'NUP98'],
#   ['em626', 'CBX3phospho'],
#   ['em627', 'STAG2'],
#   ['em628', 'DNA Accessibility'],
#   ['em629', 'total-RNA']]]

# %%
## Query 1: List all experiments with H3k27ac peak data (.BED) & by ENCODE/BLUEPRINT
(status, peaks_experiments) = server.list_experiments("", "peaks", "H3K27ac", "", "", "", ["ENCODE", "Blueprint Epigenome"], user_key)

len(peaks_experiments) #expect >400 expts
# Out:
# 791

# %%
## Query 2: List all experiments with H3k27ac signals (.bedgraph, .wig) & by ENCODE or BLUEPRINT projects
(status, signal_experiments) = server.list_experiments("", "signal", "H3K27ac", "", "", "", ["ENCODE", "Blueprint Epigenome"], user_key)
len(signal_experiments)
# Out:
# 669

# %%
## Query 3: List all experiments with RRBS data
(status, signal_experiments) = server.list_experiments("", "", "", "", "", "", ["ENCODE", "Blueprint Epigenome"], user_key)
len(signal_experiments)
# Out:
# 270
